# %%
#%autoreload
from keras.preprocessing import image
from keras import applications
from keras.models import Sequential
from keras.applications import vgg16
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.models import Model
from keras.layers import Conv2D, Conv3D,Input, ZeroPadding3D, Reshape
from keras.layers.convolutional import Convolution2D, Convolution3D, MaxPooling2D, ZeroPadding2D,ZeroPadding3D 
from keras.layers.core import Reshape
import os
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.callbacks import CSVLogger
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.optimizers import SGD
import numpy as np
import keras
import keras.backend as K
from keras.callbacks import ModelCheckpoint
#import imp
#imp.reload(parse_data)
# Out:
# Using TensorFlow backend.

# %%
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))
   # return np.linalg.norm(y_pred-y_true)/np.linalg.norm(y_true)

# %%
model_vgg16 = vgg16.VGG16(weights='imagenet', include_top=False, input_shape=(299,299,3))
input_x = Input((299,299,4))
x = Conv2D(3,(3,3), activation='relu', data_format="channels_last")(input_x)
x = ZeroPadding2D((1,1))(x)
x = Reshape((299,299,3))(x)
x = model_vgg16(x)

flatten = Flatten()
new_layer2 = Dense(1024, activation='relu', name='my_dense_2')
out2 = new_layer2(flatten(x))
x = Dense(512, activation='relu')(out2)
preds = Dense(3, activation = 'relu')(x)

model_start = Model(input_x, preds)
model_start.compile(loss='mean_squared_error', optimizer=SGD(lr=1e-5, momentum=0.9),
            metrics=[root_mean_squared_error])
model_start.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 299, 299, 4)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 297, 297, 3)       111
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 299, 299, 3)       0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 299, 299, 3)       0
# _________________________________________________________________
# vgg16 (Model)                (None, 9, 9, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# my_dense_2 (Dense)           (None, 1024)              42468352
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 57,709,490
# Trainable params: 57,709,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
object_path = "/home/zhouzixuan/proj/data/train/35/"
dev_path = "/home/zhouzixuan/proj/data/dev/35/"
filename ="vgg"
rescale=1. / 255
img_width, img_height = 299, 299

# %%
dev_num = 7
X_dev = np.empty([0,299,299,4])
y_dev = np.empty([0,3])
for k in range(dev_num):
    x_dev = np.load(dev_path+str(60+k)+"_x.npy") * rescale
    d_dev = np.load(dev_path+str(60+k)+"_d.npy")
    tmp1 = (np.concatenate((x_dev,np.expand_dims(d_dev, axis=3)), axis=3)) 
    X_dev = np.vstack([X_dev, tmp1])
    tmp2 = np.load(dev_path+str(60+k)+"_y.npy")
    y_dev = np.vstack([y_dev, tmp2])
print y_dev.shape
print X_dev.shape
# Out:
# (224, 3)
# (224, 299, 299, 4)

# %%
dev_loss = model_start.evaluate(x = X_dev, y = y_dev)
print "----val_loss & l2_error----:"
print dev_loss
# Out:
# 224/224 [==============================] - 178s 797ms/step
# ----val_loss & l2_error----:
# [2.633326836994716, 1.4532325097492762]

# %%
def train(model):
    filename = "vgg2d_"
    fh = open(filename + 'report.txt','w')
    csv_logger = CSVLogger('logvgg.csv', append=True, separator=';') 
    f_train = open(filename + 'train_report.txt',"a", 0)
    f_train_step = open(filename + 'step_report.txt',"a", 0)
    f_dev = open(filename + 'dev_report.txt',"a", 0)
    batch = 32
    epochs = 20
    batch_num = 60
    rescale=1. / 255
    filepath_best="/home/zhouzixuan/proj/data/weights.best.hdf5"
    if os.path.exists(filepath_best):
        model.load_weights(filepath_best)
        print "load weight success!"
    for e in range(4,epochs):
        print('Epoch', e)
        for b in range(batch_num):
            x_batch = np.load(object_path+str(b)+"_x.npy") * rescale
            d_batch = np.load(object_path+str(b)+"_d.npy")
            X = (np.concatenate((x_batch,np.expand_dims(d_batch, axis=3)), axis=3))           
            y_batch = np.load(object_path+str(b)+"_y.npy")            
            checkpoint = ModelCheckpoint(filepath=filepath_best,monitor='loss', verbose=1,save_best_only=True, mode='min')
            res = model.fit(X, y_batch,callbacks=[checkpoint],verbose=0)
            print str(res.history)
            f_train_step.write(str(res.history))
            f_train_step.write("\n")
        train_loss = model.evaluate(x = X, y = y_batch)
        f_train.write(str(train_loss))
        dev_loss = model.evaluate(x = X_dev, y = y_dev)
        f_dev.write(str(dev_loss))
        print "----val_loss & l2_error----:"
        print dev_loss
    f_train.close()
    f_train_step.close()
    f_dev.close()

# %%
train(model_start)
# Out:
# load weight success!
# ('Epoch', 4)
#
# Epoch 00001: loss improved from inf to 0.32366, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.32366421818733215], 'root_mean_squared_error': [0.53200662136077881]}
#
# Epoch 00001: loss improved from inf to 0.41138, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.41137605905532837], 'root_mean_squared_error': [0.57549118995666504]}
#
# Epoch 00001: loss improved from inf to 0.38326, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38325619697570801], 'root_mean_squared_error': [0.55924111604690552]}
#
# Epoch 00001: loss improved from inf to 0.35919, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.3591887354850769], 'root_mean_squared_error': [0.53829860687255859]}
#
# Epoch 00001: loss improved from inf to 0.34836, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34836003184318542], 'root_mean_squared_error': [0.54187321662902832]}
#
# Epoch 00001: loss improved from inf to 0.42649, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.42648997902870178], 'root_mean_squared_error': [0.60749924182891846]}
#
# Epoch 00001: loss improved from inf to 0.33116, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.33115610480308533], 'root_mean_squared_error': [0.51621770858764648]}
#
# Epoch 00001: loss improved from inf to 0.38912, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38912072777748108], 'root_mean_squared_error': [0.58425545692443848]}
#
# Epoch 00001: loss improved from inf to 0.40031, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.40030962228775024], 'root_mean_squared_error': [0.58265286684036255]}
#
# Epoch 00001: loss improved from inf to 0.28854, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.28853535652160645], 'root_mean_squared_error': [0.51016366481781006]}
#
# Epoch 00001: loss improved from inf to 0.34493, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34493422508239746], 'root_mean_squared_error': [0.54345566034317017]}
#
# Epoch 00001: loss improved from inf to 0.34814, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34814435243606567], 'root_mean_squared_error': [0.54031205177307129]}
#
# Epoch 00001: loss improved from inf to 0.34124, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34123623371124268], 'root_mean_squared_error': [0.54126179218292236]}
#
# Epoch 00001: loss improved from inf to 0.24611, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.24610574543476105], 'root_mean_squared_error': [0.46739673614501953]}
#
# Epoch 00001: loss improved from inf to 0.34499, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34499400854110718], 'root_mean_squared_error': [0.54403853416442871]}
#
# Epoch 00001: loss improved from inf to 0.33207, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.33206546306610107], 'root_mean_squared_error': [0.5237126350402832]}
#
# Epoch 00001: loss improved from inf to 0.43485, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.43484500050544739], 'root_mean_squared_error': [0.61407303810119629]}
#
# Epoch 00001: loss improved from inf to 0.35300, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35299527645111084], 'root_mean_squared_error': [0.55638355016708374]}
#
# Epoch 00001: loss improved from inf to 0.33835, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.33834552764892578], 'root_mean_squared_error': [0.53282862901687622]}
#
# Epoch 00001: loss improved from inf to 0.36851, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.36851030588150024], 'root_mean_squared_error': [0.55369448661804199]}
#
# Epoch 00001: loss improved from inf to 0.29683, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.29683390259742737], 'root_mean_squared_error': [0.49489197134971619]}
#
# Epoch 00001: loss improved from inf to 0.38090, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38090172410011292], 'root_mean_squared_error': [0.5776936411857605]}
#
# Epoch 00001: loss improved from inf to 0.36578, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.36578068137168884], 'root_mean_squared_error': [0.54099023342132568]}
#
# Epoch 00001: loss improved from inf to 0.37446, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.37445765733718872], 'root_mean_squared_error': [0.57214891910552979]}
#
# Epoch 00001: loss improved from inf to 0.25726, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.25725996494293213], 'root_mean_squared_error': [0.47382265329360962]}
#
# Epoch 00001: loss improved from inf to 0.33794, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.33794277906417847], 'root_mean_squared_error': [0.54451215267181396]}
#
# Epoch 00001: loss improved from inf to 0.38527, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38526713848114014], 'root_mean_squared_error': [0.55226558446884155]}
#
# Epoch 00001: loss improved from inf to 0.28627, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.28627496957778931], 'root_mean_squared_error': [0.4971049427986145]}
#
# Epoch 00001: loss improved from inf to 0.32951, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.32951223850250244], 'root_mean_squared_error': [0.54533249139785767]}
#
# Epoch 00001: loss improved from inf to 0.29595, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.2959538996219635], 'root_mean_squared_error': [0.49886220693588257]}
#
# Epoch 00001: loss improved from inf to 0.33641, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.33641397953033447], 'root_mean_squared_error': [0.54465305805206299]}
#
# Epoch 00001: loss improved from inf to 0.33617, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.33616909384727478], 'root_mean_squared_error': [0.529258131980896]}
#
# Epoch 00001: loss improved from inf to 0.32992, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.32992419600486755], 'root_mean_squared_error': [0.52845633029937744]}
#
# Epoch 00001: loss improved from inf to 0.30588, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.3058781623840332], 'root_mean_squared_error': [0.51479959487915039]}
#
# Epoch 00001: loss improved from inf to 0.35155, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35154649615287781], 'root_mean_squared_error': [0.55768811702728271]}
#
# Epoch 00001: loss improved from inf to 0.39620, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.39620131254196167], 'root_mean_squared_error': [0.57511258125305176]}
#
# Epoch 00001: loss improved from inf to 0.31929, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.31928709149360657], 'root_mean_squared_error': [0.51071864366531372]}
#
# Epoch 00001: loss improved from inf to 0.39040, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.39040303230285645], 'root_mean_squared_error': [0.57322919368743896]}
#
# Epoch 00001: loss improved from inf to 0.29336, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.2933577299118042], 'root_mean_squared_error': [0.51235473155975342]}
#
# Epoch 00001: loss improved from inf to 0.41353, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.41353464126586914], 'root_mean_squared_error': [0.59491884708404541]}
#
# Epoch 00001: loss improved from inf to 0.35415, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35415351390838623], 'root_mean_squared_error': [0.52425414323806763]}
#
# Epoch 00001: loss improved from inf to 0.28299, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.28299322724342346], 'root_mean_squared_error': [0.47448879480361938]}
#
# Epoch 00001: loss improved from inf to 0.25039, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.25038892030715942], 'root_mean_squared_error': [0.45617520809173584]}
#
# Epoch 00001: loss improved from inf to 0.23419, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.2341865748167038], 'root_mean_squared_error': [0.42239919304847717]}
#
# Epoch 00001: loss improved from inf to 0.26146, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.26145955920219421], 'root_mean_squared_error': [0.45768365263938904]}
#
# Epoch 00001: loss improved from inf to 0.35913, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.3591272234916687], 'root_mean_squared_error': [0.56349492073059082]}
#
# Epoch 00001: loss improved from inf to 0.38258, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38257914781570435], 'root_mean_squared_error': [0.5514984130859375]}
#
# Epoch 00001: loss improved from inf to 0.35090, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35090148448944092], 'root_mean_squared_error': [0.54857277870178223]}
#
# Epoch 00001: loss improved from inf to 0.34038, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34038454294204712], 'root_mean_squared_error': [0.5361897349357605]}
#
# Epoch 00001: loss improved from inf to 0.29107, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.29107177257537842], 'root_mean_squared_error': [0.49082666635513306]}
#
# Epoch 00001: loss improved from inf to 0.35680, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35679888725280762], 'root_mean_squared_error': [0.55788648128509521]}
#
# Epoch 00001: loss improved from inf to 0.40241, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.40241092443466187], 'root_mean_squared_error': [0.58260750770568848]}
#
# Epoch 00001: loss improved from inf to 0.36252, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.36251941323280334], 'root_mean_squared_error': [0.57115441560745239]}
#
# Epoch 00001: loss improved from inf to 0.26877, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.26876923441886902], 'root_mean_squared_error': [0.47912654280662537]}
#
# Epoch 00001: loss improved from inf to 0.43829, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.43829306960105896], 'root_mean_squared_error': [0.61311674118041992]}
#
# Epoch 00001: loss improved from inf to 0.26948, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.26947614550590515], 'root_mean_squared_error': [0.46914219856262207]}
#
# Epoch 00001: loss improved from inf to 0.35525, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35524916648864746], 'root_mean_squared_error': [0.5510285496711731]}
#
# Epoch 00001: loss improved from inf to 0.37075, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.37074685096740723], 'root_mean_squared_error': [0.56341999769210815]}
#
# Epoch 00001: loss improved from inf to 0.29144, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.29143702983856201], 'root_mean_squared_error': [0.5057106614112854]}
#
# Epoch 00001: loss improved from inf to 0.39043, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.39043337106704712], 'root_mean_squared_error': [0.57141125202178955]}
# 32/32 [==============================] - 26s 806ms/step
# 224/224 [==============================] - 180s 805ms/step
# ----val_loss & l2_error----:
# [0.36296092186655315, 0.55527079956872127]
# ('Epoch', 5)
#
# Epoch 00001: loss improved from inf to 0.32217, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.32217472791671753], 'root_mean_squared_error': [0.53077363967895508]}
#
# Epoch 00001: loss improved from inf to 0.40925, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.40924850106239319], 'root_mean_squared_error': [0.57457655668258667]}
#
# Epoch 00001: loss improved from inf to 0.38478, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38478314876556396], 'root_mean_squared_error': [0.56068122386932373]}
#
# Epoch 00001: loss improved from inf to 0.35928, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35928076505661011], 'root_mean_squared_error': [0.53883183002471924]}
#
# Epoch 00001: loss improved from inf to 0.34937, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.3493725061416626], 'root_mean_squared_error': [0.54210925102233887]}
#
# Epoch 00001: loss improved from inf to 0.42717, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.42716988921165466], 'root_mean_squared_error': [0.6080697774887085]}
#
# Epoch 00001: loss improved from inf to 0.33081, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.33081001043319702], 'root_mean_squared_error': [0.5179864764213562]}
#
# Epoch 00001: loss improved from inf to 0.38790, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38789546489715576], 'root_mean_squared_error': [0.58381861448287964]}
#
# Epoch 00001: loss improved from inf to 0.39883, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.39883071184158325], 'root_mean_squared_error': [0.58137595653533936]}
#
# Epoch 00001: loss improved from inf to 0.28799, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.28799161314964294], 'root_mean_squared_error': [0.51031959056854248]}
#
# Epoch 00001: loss improved from inf to 0.34291, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34291338920593262], 'root_mean_squared_error': [0.54191756248474121]}
#
# Epoch 00001: loss improved from inf to 0.34615, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34614887833595276], 'root_mean_squared_error': [0.53923338651657104]}
#
# Epoch 00001: loss improved from inf to 0.34065, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34065216779708862], 'root_mean_squared_error': [0.54117262363433838]}
#
# Epoch 00001: loss improved from inf to 0.24462, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.2446228563785553], 'root_mean_squared_error': [0.46631520986557007]}
#
# Epoch 00001: loss improved from inf to 0.34402, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34402328729629517], 'root_mean_squared_error': [0.5437086820602417]}
#
# Epoch 00001: loss improved from inf to 0.33072, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.3307228684425354], 'root_mean_squared_error': [0.52193641662597656]}
#
# Epoch 00001: loss improved from inf to 0.43547, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.43546909093856812], 'root_mean_squared_error': [0.61465644836425781]}
#
# Epoch 00001: loss improved from inf to 0.35096, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35096099972724915], 'root_mean_squared_error': [0.55428725481033325]}
#
# Epoch 00001: loss improved from inf to 0.33867, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.33867156505584717], 'root_mean_squared_error': [0.53359562158584595]}
#
# Epoch 00001: loss improved from inf to 0.36865, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.36865118145942688], 'root_mean_squared_error': [0.55451953411102295]}
#
# Epoch 00001: loss improved from inf to 0.29675, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.29674744606018066], 'root_mean_squared_error': [0.49531751871109009]}
#
# Epoch 00001: loss improved from inf to 0.38064, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38063901662826538], 'root_mean_squared_error': [0.57781720161437988]}
#
# Epoch 00001: loss improved from inf to 0.36529, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.36529174447059631], 'root_mean_squared_error': [0.54052555561065674]}
#
# Epoch 00001: loss improved from inf to 0.37358, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.37357988953590393], 'root_mean_squared_error': [0.57141619920730591]}
#
# Epoch 00001: loss improved from inf to 0.25677, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.25676757097244263], 'root_mean_squared_error': [0.47353583574295044]}
#
# Epoch 00001: loss improved from inf to 0.33810, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.33810186386108398], 'root_mean_squared_error': [0.54462611675262451]}
#
# Epoch 00001: loss improved from inf to 0.38359, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38358503580093384], 'root_mean_squared_error': [0.55133545398712158]}
#
# Epoch 00001: loss improved from inf to 0.28598, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.28597515821456909], 'root_mean_squared_error': [0.49674996733665466]}
#
# Epoch 00001: loss improved from inf to 0.32877, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.32876995205879211], 'root_mean_squared_error': [0.54478967189788818]}
#
# Epoch 00001: loss improved from inf to 0.29575, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.29574733972549438], 'root_mean_squared_error': [0.49853640794754028]}
#
# Epoch 00001: loss improved from inf to 0.33493, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.3349345326423645], 'root_mean_squared_error': [0.54375994205474854]}
#
# Epoch 00001: loss improved from inf to 0.33536, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.33535611629486084], 'root_mean_squared_error': [0.52857136726379395]}
#
# Epoch 00001: loss improved from inf to 0.32845, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.32845002412796021], 'root_mean_squared_error': [0.52758198976516724]}
#
# Epoch 00001: loss improved from inf to 0.30386, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.30386394262313843], 'root_mean_squared_error': [0.51263439655303955]}
#
# Epoch 00001: loss improved from inf to 0.35144, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35143923759460449], 'root_mean_squared_error': [0.55777359008789062]}
#
# Epoch 00001: loss improved from inf to 0.39556, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.39555725455284119], 'root_mean_squared_error': [0.57499110698699951]}
#
# Epoch 00001: loss improved from inf to 0.31787, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.31787323951721191], 'root_mean_squared_error': [0.50963985919952393]}
#
# Epoch 00001: loss improved from inf to 0.38910, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38909626007080078], 'root_mean_squared_error': [0.57257866859436035]}
#
# Epoch 00001: loss improved from inf to 0.29391, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.29390937089920044], 'root_mean_squared_error': [0.51308929920196533]}
#
# Epoch 00001: loss improved from inf to 0.41206, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.41205942630767822], 'root_mean_squared_error': [0.59371292591094971]}
#
# Epoch 00001: loss improved from inf to 0.35436, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35435536503791809], 'root_mean_squared_error': [0.52458465099334717]}
#
# Epoch 00001: loss improved from inf to 0.28186, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.28186428546905518], 'root_mean_squared_error': [0.47322928905487061]}
#
# Epoch 00001: loss improved from inf to 0.24944, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.24943819642066956], 'root_mean_squared_error': [0.45537188649177551]}
#
# Epoch 00001: loss improved from inf to 0.23433, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.23432813584804535], 'root_mean_squared_error': [0.42271095514297485]}
#
# Epoch 00001: loss improved from inf to 0.26166, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.26165914535522461], 'root_mean_squared_error': [0.45811569690704346]}
#
# Epoch 00001: loss improved from inf to 0.35833, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35833320021629333], 'root_mean_squared_error': [0.56266796588897705]}
#
# Epoch 00001: loss improved from inf to 0.38161, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.38161167502403259], 'root_mean_squared_error': [0.55090296268463135]}
#
# Epoch 00001: loss improved from inf to 0.35048, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35048195719718933], 'root_mean_squared_error': [0.54819542169570923]}
#
# Epoch 00001: loss improved from inf to 0.34073, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.34072813391685486], 'root_mean_squared_error': [0.53660380840301514]}
#
# Epoch 00001: loss improved from inf to 0.29127, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.2912747859954834], 'root_mean_squared_error': [0.49104756116867065]}
#
# Epoch 00001: loss improved from inf to 0.35559, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35558855533599854], 'root_mean_squared_error': [0.55700701475143433]}
#
# Epoch 00001: loss improved from inf to 0.40131, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.40131074190139771], 'root_mean_squared_error': [0.58212697505950928]}
#
# Epoch 00001: loss improved from inf to 0.36164, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.36164397001266479], 'root_mean_squared_error': [0.57048326730728149]}
#
# Epoch 00001: loss improved from inf to 0.26880, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.26880490779876709], 'root_mean_squared_error': [0.47939950227737427]}
#
# Epoch 00001: loss improved from inf to 0.43781, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.43781298398971558], 'root_mean_squared_error': [0.61255407333374023]}
#
# Epoch 00001: loss improved from inf to 0.26837, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.26836502552032471], 'root_mean_squared_error': [0.46828317642211914]}
#
# Epoch 00001: loss improved from inf to 0.35427, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.35426598787307739], 'root_mean_squared_error': [0.54996722936630249]}
#
# Epoch 00001: loss improved from inf to 0.36977, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.36977335810661316], 'root_mean_squared_error': [0.56253677606582642]}
#
# Epoch 00001: loss improved from inf to 0.29133, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.2913345992565155], 'root_mean_squared_error': [0.50579190254211426]}
#
# Epoch 00001: loss improved from inf to 0.39072, saving model to /home/zhouzixuan/proj/data/weights.best.hdf5
# {'loss': [0.39072078466415405], 'root_mean_squared_error': [0.57175248861312866]}
# 32/32 [==============================] - 26s 799ms/step
# 224/224 [==============================] - 179s 800ms/step
# ----val_loss & l2_error----:
# [0.36271456735474722, 0.55499953883034847]
# ('Epoch', 6)
